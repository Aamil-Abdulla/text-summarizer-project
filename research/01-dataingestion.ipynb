# %%
import os
import sys
sys.path.append(r"c:\Users\Admin\Desktop\text-summarizer\text-summarizer-project\src")

# %%
# %pwd
# Out:
# 'c:\\Users\\Admin\\Desktop\\text-summarizer\\text-summarizer-project'

# %%
os.chdir("../")

# %%
pwd
# Out:
# 'c:\\Users\\Admin\\Desktop\\text-summarizer'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
import os
for root, dirs, files in os.walk(".", topdown=True):
    print(root)
    break
# Out:
# .

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Admin\\Desktop\\text-summarizer'

# %%
import os
os.path.isdir("text_summarizer")
# Out:
# False

# %%
import os
os.listdir()
# Out:
# ['logs', 'text-summarizer-project']

# %%
# !pip install python-box

# %%
import sys
sys.path.append("/content/text-summarizer-project")
sys.path.append("/content/text-summarizer-project/src")

# %%
from text_summarizer.constants import *
from text_summarizer.utils.common import read_yaml, create_directories

# %%
from text_summarizer.constants import *
from text_summarizer.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(self, config_filepath=CONFIG_FILE_PATH, params_filepath=PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([Path(config.root_dir)])

        data_ingestion_config = DataIngestionConfig(
            root_dir=Path(config.root_dir),
            source_URL=config.source_URL,
            local_data_file=Path(config.local_data_file),
            unzip_dir=Path(config.unzip_dir)
        )

        return data_ingestion_config

# %%
import os
print(os.listdir(r"c:\Users\Admin\Desktop\text-summarizer"))
# Out:
# ['logs', 'text-summarizer-project']

# %%
from text_summarizer.utils.common import get_size

# %%
import os
import urllib.request as request
from zipfile import ZipFile
from text_summarizer.utils.common import get_size
from text_summarizer.logging import logger

# %%
class DataIngestion:
        def __init__(self, config: DataIngestionConfig):
            self.config = config
        
        def download_data(self) -> str:
            logger.info("Starting data download...")
            filename = os.path.basename(self.config.source_URL)
            download_path = self.config.root_dir / filename

            logger.info(f"Downloading data from {self.config.source_URL} to {download_path}")
            request.urlretrieve(self.config.source_URL, download_path)
            logger.info(f"Data downloaded successfully! File size: {get_size(download_path)}")

            return str(download_path)
        
        def extract_zip_file(self, zip_file_path: str):
            logger.info(f"Extracting zip file: {zip_file_path} to directory: {self.config.unzip_dir}")
            with ZipFile(zip_file_path, 'r') as zip_ref:
                zip_ref.extractall(self.config.unzip_dir)
            logger.info("Extraction completed successfully.")

# %%
os.chdir("c:/Users/Admin/Desktop/text-summarizer/text-summarizer-project")

# %%
from src.text_summarizer.components.data_ingestion import DataIngestion

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    
    zip_path = data_ingestion.download_data()  # returns actual path
    data_ingestion.extract_zip_file(zip_file_path=zip_path)
except Exception as e:
    raise
# Out:
# 2025-12-01 16:31:26,512 - INFO - common - YAML file: C:\Users\Admin\Desktop\text-summarizer\text-summarizer-project\config\config.yaml loaded successfully.
# 2025-12-01 16:31:26,516 - INFO - common - YAML file: C:\Users\Admin\Desktop\text-summarizer\text-summarizer-project\config\params.yaml loaded successfully.
# 2025-12-01 16:31:26,516 - INFO - common - Directory created at: artifacts
# 2025-12-01 16:31:26,516 - INFO - common - Directory created at: artifacts\data_ingestion
# 2025-12-01 16:31:26,516 - INFO - data_ingestion - Starting data download...
# 2025-12-01 16:31:26,516 - INFO - data_ingestion - Downloading data from https://github.com/Aamil-Abdulla/text-summarizer-project-zip/raw/refs/heads/main/samsumdata.zip to artifacts\data_ingestion\samsumdata.zip
# 2025-12-01 16:31:41,959 - INFO - common - Size of file at artifacts\data_ingestion\samsumdata.zip: 23073.25 KB
# 2025-12-01 16:31:41,959 - INFO - data_ingestion - Data downloaded successfully! File size: 23073.25 KB
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Admin\Desktop\text-summarizer\text-summarizer-project

# %%
# !type src\text_summarizer\utils\__init__.py
